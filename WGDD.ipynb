# %% [markdown]
# #**WhatsApp GDrive Downloader**
#
# Inspiration: https://github.com/B16f00t/whapa
#
# Adaptation by https://t.me/limontec
#
# DISCLAIMER: TO BE USED FOR EDUCATIONAL PURPOSES ONLY.
#
# Don't type your password... go to the URL: https://myaccount.google.com/apppasswords
#
# Then select Application: Other.
#
# Write down: Whapa
#
# A password will be display.
#
# Then you must write the password bellow.
#
# v0.1.1

# %%
#@markdown <center><h2>Add support Python 3.8 Google Colab</h2></center><br>
# !wget -O mini.sh https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# !chmod +x mini.sh
# !bash ./mini.sh -b -f -p /usr/local
# !conda install -q -y jupyter
# !conda install -q -y google-colab -c conda-forge
# !python -m ipykernel install --name "py38" --user
# !python3 -m pip install --upgrade pip
# !python3 --version
# !pip --version
# Out:
# --2024-12-05 17:51:20--  https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89817099 (86M) [application/x-sh]
# Saving to: ‘mini.sh’
#
# mini.sh             100%[===================>]  85.66M   189MB/s    in 0.5s
#
# 2024-12-05 17:51:20 (189 MB/s) - ‘mini.sh’ saved [89817099/89817099]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py38_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py38_0
#     - cffi==1.14.0=py38h2e261b9_0
#     - chardet==3.0.4=py38_1003
#     - conda-package-handling==1.6.0=py38h7b6447c_0
# ...

# %%
# Complete WhatsApp Google Drive Backup Extractor
import os
from google.colab import files
from IPython.display import clear_output

# Install required packages
# !pip install certifi -q
# !git clone https://github.com/limontec/whapa 2>/dev/null || (cd whapa && git pull)
# !cd whapa && pip3 install --upgrade -r ./doc/requirements.txt -q
# !apt-get install -y ca-certificates >/dev/null 2>&1
# !update-ca-certificates >/dev/null 2>&1

# Set up SSL certificates
import certifi
os.environ['REQUESTS_CA_BUNDLE'] = certifi.where()
os.environ['SSL_CERT_FILE'] = certifi.where()

# User configurations
email = "haidyraafdbdhdb@gmail.com"
password = "kbuq cwvx tweu orhh"
phone = "20123456789" # please dont remove the 2 in the beginning
oauth = "\"\""

# Create config file
config_content = f'''[report]
company =
record =
unit =
examiner =
notes =

[google-auth]
gmail = {email}
password = {password}
oauth = {oauth}
android_id = 0000000000000000
celnumbr = {phone}

[icloud-auth]
icloud = alias@icloud.com
passw = yourpassword'''

# Ensure config directory exists and write config
os.makedirs('whapa/cfg', exist_ok=True)
with open('whapa/cfg/settings.cfg', 'w') as cfg:
    cfg.write(config_content)

# Initial check to show available backups
print("Checking available WhatsApp backups...")
# !python whapa/libs/whagodri.py -i

print("\nStarting backup download process...")
# !python3 whapa/libs/whagodri.py -s

# Create backup archive if files exist
backup_name = f'whatsapp_backup_{phone}'
try:
    if os.path.exists(f'/content/{phone}/files/'):
        print("\nCreating backup archive...")
        # !cd /content/{phone}/files/ && zip -9 -r {backup_name}.zip Backups Databases Media _INTERNAL_FILES_
        # !mv /content/{phone}/files/{backup_name}.zip /content/
        print("\nBackup archive created successfully!")
        files.download(f'{backup_name}.zip')
        print(f"\nIf download doesn't start automatically, find your backup at: /content/{backup_name}.zip")
    else:
        print("\nSearching for backup files in alternative locations...")
        # !find /content -type d -name "Backups" -o -name "Databases" -o -name "Media"
except Exception as e:
    print(f"\nError during backup process: {str(e)}")
    print("Please check the content folder for your backup files manually.")

print("\nProcess completed!")
# Out:
# Already up to date.
# Checking available WhatsApp backups...
#
#      __      __.__             ________      ________        .__
#     /  \    /  \  |__ _____   /  _____/  ____\______ \_______|__|
#     \   \/\/   /  |  \\__  \ /   \  ___ /  _ \|    |  \_  __ \  |
#      \        /|   Y  \/ __ \\    \_\  (  <_> )    `   \  | \/  |
#       \__/\  / |___|  (____  /\______  /\____/_______  /__|  |__|
#            \/       \/     \/        \/              \/
#
#     -------------- Whatsapp Google Drive Extractor --------------
# [i] Searching...
#
# Requesting access to Google...
# Granted.
# Requesting authentication for Google Drive...
# Granted.
# [i] Backup name     : clients/wa/backups/201068520946
# [-] Whatsapp version: 2.24.23.78-play-release
# [-] Backup protected: None
# [-] Backup upload   : 2024-12-05T17:06:25.446218Z
# [-] Backup size     : 199069 Bytes (194 kB)
# [+] Backup metadata
#     [-] Backup Frequency         : 4
#     [-] Backup Network Settings  : 0
# ...
